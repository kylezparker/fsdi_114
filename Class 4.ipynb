# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SinglyLinkedList:
    def __init__(self):
        self.head = None
        
    def append(self,item):
        if not self.head:
            self.head = Node(item)
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = Node(item)
            
    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
        current = self.head.next
        while current:
            out += " , %s" % current.data
            current = current.next
        out += "]"
        return out
    
    def insert (self, index, item):
        if self.head == None:
            self.head = Node(item)
        else:
            if index == 0:
                node = Node(item)
                temp = self.head
                self.head = node
                self.head.next = temp
            else:
                current= self.head
                prev = None
                counter = 0
                while current.next and counter != index:
                    prev = current 
                    current = current.next
                    counter = counter + 1
                if counter == index:
                    node = Node(item)
                    prev.next = node
                    node.next = current
                else:
                    node = Node(item)
                    current.next= node
                    
                    
            
            
    
    def remove (self, target):
        pass

# %%
sll= SinglyLinkedList()
for num in range(1,4):
    sll.append(num)
print(sll)
sll.insert(0,0)
sll.insert(2,1.5)
print(sll)
sll.insert(100,5)
# Out:
# [1 , 2 , 3]
# [0 , 1 , 1.5 , 2 , 3]

# %%
class DNode:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev= None
        
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        
    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
        current = self.head.next
        while current:
            out += " , %s" % current.data
            current = current.next
        out += "]"
        return out
        
    def append(self, value):
        if not self.head:
            self.head = DNode(value)
        else: 
            current= self.head
            while current.next:
                current= current.next
            node = DNode(value)
            current.next= node
            node.prev = current        #this is whats diffrent from sll
    
    def insert(self,index,value):
        #this is homework
        pass
    
    def remove(self, value):
        current = self.head
        while current.next and current.data != value:
            current=current.next
        if curent.data == value:
            if current.prev:
                temp=current.prev
                temp.next=current.next
                next_node= current.next
                next_node.prev = temp
            else:
                if not current.next:
                    self.head=None
                else:
                    self.head = current.next
                    self.head.prev=None
            else:
                raise ValueError("The value wasnt found")
           
    def size(self):
        #this is homework
        pass
    
    def index(self,value):
        #this is homework
        current=self.head
        counter=0
        if current.head ==value
            return counter
        while current.next:
            counter+=1
            current=current.next
            if current.next == value
                return counter
        else:
            raise ValueError("The target value is not present")
        
        
        
# AAA
# Analysis/Assessment, Assembly, Action

# %%
dll= DoublyLinkedList()
for i in range(10):
    dll.append(i)

print(dll)
